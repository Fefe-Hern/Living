# %%
import pandas as pd
import numpy as np

# %%
redfin = pd.read_csv('redfin_market_tracker_LI.csv')
redfin.head()
# Out:
#    Unnamed: 0 period_begin  period_end  period_duration region_type  \
# 0        1146   2017-08-01  2017-08-31               30      county
# 1        2300   2018-02-01  2018-02-28               30      county
# 2        2885   2021-10-01  2021-10-31               30      county
# 3        4326   2023-08-01  2023-08-31               30      county
# 4        4380   2013-04-01  2013-04-30               30      county
#
#    region_type_id  table_id is_seasonally_adjusted              region  city  \
# 0               5      1996                      f  Suffolk County, NY   NaN
# 1               5      1996                      f  Suffolk County, NY   NaN
# 2               5      1996                      f  Suffolk County, NY   NaN
# 3               5      1996                      f  Suffolk County, NY   NaN
# 4               5      1996                      f  Suffolk County, NY   NaN
#
#    ... sold_above_list_yoy price_drops price_drops_mom  price_drops_yoy  \
# 0  ...           -0.018610    0.165706       -0.031015        -0.045004
# 1  ...           -0.144231    0.138462       -0.039621         0.030618
# 2  ...            0.034615    0.148148        0.010217        -0.151852
# 3  ...           -0.135338    0.052632        0.002632        -0.072368
# 4  ...           -0.005694    0.178679        0.036528        -0.010062
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.094444                     0.002420
# 1                 0.000000                    -0.133333
# 2                 0.071429                    -0.261905
# 3                 0.600000                     0.327273
# 4                 0.148196                    -0.005650
#
#    off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                    -0.014083    Nassau County, NY
# 1                    -0.090909    Nassau County, NY
# 2                    -0.011905    Nassau County, NY
# 3                     0.336842    Nassau County, NY
# 4                     0.016120    Nassau County, NY
#
#    parent_metro_region_metro_code         last_updated
# 0                         35004.0  2023-10-29 14:25:50
# 1                         35004.0  2023-10-29 14:25:50
# 2                         35004.0  2023-10-29 14:25:50
# 3                         35004.0  2023-10-29 14:25:50
# 4                         35004.0  2023-10-29 14:25:50
#
# [5 rows x 59 columns]

# %%
redfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Data columns (total 59 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      1406 non-null   int64
#  1   period_begin                    1406 non-null   object
#  2   period_end                      1406 non-null   object
#  3   period_duration                 1406 non-null   int64
#  4   region_type                     1406 non-null   object
#  5   region_type_id                  1406 non-null   int64
#  6   table_id                        1406 non-null   int64
#  7   is_seasonally_adjusted          1406 non-null   object
#  8   region                          1406 non-null   object
#  9   city                            0 non-null      float64
#  10  state                           1406 non-null   object
#  11  state_code                      1406 non-null   object
#  12  property_type                   1406 non-null   object
#  13  property_type_id                1406 non-null   int64
#  14  median_sale_price               1406 non-null   float64
#  15  median_sale_price_mom           1402 non-null   float64
#  16  median_sale_price_yoy           1402 non-null   float64
#  17  median_list_price               1403 non-null   float64
#  18  median_list_price_mom           1396 non-null   float64
#  19  median_list_price_yoy           1396 non-null   float64
#  20  median_ppsf                     1395 non-null   float64
#  21  median_ppsf_mom                 1381 non-null   float64
#  22  median_ppsf_yoy                 1377 non-null   float64
#  23  median_list_ppsf                1403 non-null   float64
#  24  median_list_ppsf_mom            1396 non-null   float64
#  25  median_list_ppsf_yoy            1396 non-null   float64
#  26  homes_sold                      1406 non-null   float64
#  27  homes_sold_mom                  1402 non-null   float64
#  28  homes_sold_yoy                  1402 non-null   float64
#  29  pending_sales                   1388 non-null   float64
#  30  pending_sales_mom               1369 non-null   float64
#  31  pending_sales_yoy               1365 non-null   float64
#  32  new_listings                    1403 non-null   float64
#  33  new_listings_mom                1396 non-null   float64
#  34  new_listings_yoy                1396 non-null   float64
#  35  inventory                       1406 non-null   float64
#  36  inventory_mom                   1402 non-null   float64
#  37  inventory_yoy                   1402 non-null   float64
#  38  months_of_supply                1406 non-null   float64
#  39  months_of_supply_mom            1402 non-null   float64
#  40  months_of_supply_yoy            1402 non-null   float64
#  41  median_dom                      1406 non-null   float64
#  42  median_dom_mom                  1402 non-null   float64
#  43  median_dom_yoy                  1402 non-null   float64
#  44  avg_sale_to_list                1405 non-null   float64
#  45  avg_sale_to_list_mom            1400 non-null   float64
#  46  avg_sale_to_list_yoy            1400 non-null   float64
#  47  sold_above_list                 1406 non-null   float64
#  48  sold_above_list_mom             1402 non-null   float64
#  49  sold_above_list_yoy             1402 non-null   float64
#  50  price_drops                     1395 non-null   float64
#  51  price_drops_mom                 1383 non-null   float64
#  52  price_drops_yoy                 1382 non-null   float64
#  53  off_market_in_two_weeks         1388 non-null   float64
#  54  off_market_in_two_weeks_mom     1369 non-null   float64
#  55  off_market_in_two_weeks_yoy     1365 non-null   float64
#  56  parent_metro_region             1406 non-null   object
#  57  parent_metro_region_metro_code  1406 non-null   float64
#  58  last_updated                    1406 non-null   object
# dtypes: float64(44), int64(5), object(10)
# memory usage: 648.2+ KB

# %% [markdown]
# Notes:
# - possible dependent variable: median sale price
# - fewer null values (will probably impute or fill with 0)
# - also has info on how fast houses leave the market (**)
