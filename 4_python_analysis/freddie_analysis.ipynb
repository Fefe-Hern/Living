# %%
from sklearn import datasets
from sklearn import model_selection  
from sklearn import linear_model
from sklearn import metrics
from sklearn import tree
from sklearn import neighbors
from sklearn import svm
from sklearn import ensemble
from sklearn import cluster

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

# %%
# Import LI_freddie.csv from F:/Programming/homeli/reviewed_data/Freddie Mac
# We will transform this into a scikit-learn dataset

freddie22 = pd.read_csv('F:/Programming/homeli/reviewed_data/Freddie Mac/LI_freddie.csv', header=0)
orig_headers = list(freddie22.columns.values)
freddie22.info()

# Headers given: Used to help copilot help suggest columns.
# credit_score,first_payment_date,mortgage_insurance_percentage,number_of_units,original_combined_loan_to_value,original_debt_to_income_ratio,original_upb,original_loan_to_value,original_interest_rate,property_type,number_of_borrowers,seller_name,servicer_name
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4654 entries, 0 to 4653
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   credit_score                     4654 non-null   int64
#  1   first_payment_date               4654 non-null   int64
#  2   mortgage_insurance_percentage    4654 non-null   int64
#  3   number_of_units                  4654 non-null   int64
#  4   original_combined_loan_to_value  4654 non-null   int64
#  5   original_debt_to_income_ratio    4654 non-null   int64
#  6   original_upb                     4654 non-null   int64
#  7   original_loan_to_value           4654 non-null   int64
#  8   original_interest_rate           4654 non-null   float64
#  9   property_type                    4654 non-null   object
#  10  number_of_borrowers              4654 non-null   int64
#  11  seller_name                      4654 non-null   object
# ...

# %%
plt.scatter(freddie22['original_interest_rate'], freddie22['original_upb'])
